# %% [markdown]
# # Look until trusted (activity 398)
#
# Challenge the impact ranking. Survivors copy into `streamlit/data/promoted_eda.yaml`.
# This notebook is **not** the stakeholder story. Restart & Run All. Pin QueryExecutionIds.

# %%
print("Look at the whole cycle first (Delivery cycle page / published-findings cells 1–2).")
print("Promote a check only if views exist, n+unit labeled, and it explains or corrected the ranking.")
